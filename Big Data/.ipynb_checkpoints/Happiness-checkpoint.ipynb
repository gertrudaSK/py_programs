# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('happiness.csv')

# %%
data.head()
# Out:
#        Country  Score  Life Expectancy  GDP Per Capita  Crime Index  \
# 0  Afghanistan  3.203            65.98      502.115487        76.63
# 1      Albania  4.719            78.96     5352.857411        40.30
# 2      Algeria  5.211            77.50     3948.343279        48.33
# 3    Argentina  6.086            77.17    10006.148970        62.55
# 4      Armenia  4.559            75.55     4622.733493        22.00
#
#    Death Rate  Birth rate  Marriage rate  Divorce rate  Literacy rate  ...  \
# 0       6.423      32.487            NaN           NaN       43.01972  ...
# 1       7.898      11.780            7.8           1.9       98.14115  ...
# 2       4.716      24.282           10.1           1.6       81.40784  ...
# 3       7.609      17.021            NaN           NaN       99.00387  ...
# 4       9.857      13.987            6.0           1.0            NaN  ...
#
#    Unemployment rate  Fossil fuels  Net migration  Diabetes Prevalance  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              147 non-null    object
#  1   Score                147 non-null    float64
#  2   Life Expectancy      147 non-null    float64
#  3   GDP Per Capita       139 non-null    float64
#  4   Crime Index          110 non-null    float64
#  5   Death Rate           147 non-null    float64
#  6   Birth rate           147 non-null    float64
#  7   Marriage rate        87 non-null     float64
#  8   Divorce rate         88 non-null     float64
#  9   Literacy rate        61 non-null     float64
#  10  Electricity access   147 non-null    float64
#  11  Unemployment rate    147 non-null    float64
#  12  Fossil fuels         120 non-null    float64
#  13  Net migration        147 non-null    int64
#  14  Diabetes Prevalance  147 non-null    float64
# ...

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False)

# %%
data = data.fillna(value=data.mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              147 non-null    object
#  1   Score                147 non-null    float64
#  2   Life Expectancy      147 non-null    float64
#  3   GDP Per Capita       147 non-null    float64
#  4   Crime Index          147 non-null    float64
#  5   Death Rate           147 non-null    float64
#  6   Birth rate           147 non-null    float64
#  7   Marriage rate        147 non-null    float64
#  8   Divorce rate         147 non-null    float64
#  9   Literacy rate        147 non-null    float64
#  10  Electricity access   147 non-null    float64
#  11  Unemployment rate    147 non-null    float64
#  12  Fossil fuels         147 non-null    float64
#  13  Net migration        147 non-null    int64
#  14  Diabetes Prevalance  147 non-null    float64
# ...

# %%
print("number of countries in data:", str(len(data.index)))
# Out:
# number of countries in data: 147

# %%
data['Score'].max()
# Out:
# 7.769

# %%
data['Score'].min()
# Out:
# 2.853

# %%
data.isnull()
# Out:
#      Country  Score  Life Expectancy  GDP Per Capita  Crime Index  Death Rate  \
# 0      False  False            False           False        False       False
# 1      False  False            False           False        False       False
# 2      False  False            False           False        False       False
# 3      False  False            False           False        False       False
# 4      False  False            False           False        False       False
# ..       ...    ...              ...             ...          ...         ...
# 142    False  False            False           False        False       False
# 143    False  False            False           False        False       False
# 144    False  False            False           False        False       False
# 145    False  False            False           False        False       False
# 146    False  False            False           False        False       False
#
# ...

# %%
data.isnull().sum()
# Out:
# Country                0
# Score                  0
# Life Expectancy        0
# GDP Per Capita         0
# Crime Index            0
# Death Rate             0
# Birth rate             0
# Marriage rate          0
# Divorce rate           0
# Literacy rate          0
# Electricity access     0
# Unemployment rate      0
# Fossil fuels           0
# Net migration          0
# Diabetes Prevalance    0
# HIV Prevalance         0
# Rights Strength        0
# Women in Parliament    0
# Car Accidents          0
# Urban Population       0
# Average Rainfall       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              147 non-null    object
#  1   Score                147 non-null    float64
#  2   Life Expectancy      147 non-null    float64
#  3   GDP Per Capita       147 non-null    float64
#  4   Crime Index          147 non-null    float64
#  5   Death Rate           147 non-null    float64
#  6   Birth rate           147 non-null    float64
#  7   Marriage rate        147 non-null    float64
#  8   Divorce rate         147 non-null    float64
#  9   Literacy rate        147 non-null    float64
#  10  Electricity access   147 non-null    float64
#  11  Unemployment rate    147 non-null    float64
#  12  Fossil fuels         147 non-null    float64
#  13  Net migration        147 non-null    int64
#  14  Diabetes Prevalance  147 non-null    float64
# ...

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False)

# %%
data.head()
# Out:
#        Country  Score  Life Expectancy  GDP Per Capita  Crime Index  \
# 0  Afghanistan  3.203            65.98      502.115487        76.63
# 1      Albania  4.719            78.96     5352.857411        40.30
# 2      Algeria  5.211            77.50     3948.343279        48.33
# 3    Argentina  6.086            77.17    10006.148970        62.55
# 4      Armenia  4.559            75.55     4622.733493        22.00
#
#    Death Rate  Birth rate  Marriage rate  Divorce rate  Literacy rate  ...  \
# 0       6.423      32.487        6.01954      1.891477      43.019720  ...
# 1       7.898      11.780        7.80000      1.900000      98.141150  ...
# 2       4.716      24.282       10.10000      1.600000      81.407840  ...
# 3       7.609      17.021        6.01954      1.891477      99.003870  ...
# 4       9.857      13.987        6.00000      1.000000      84.530033  ...
#
#    Unemployment rate  Fossil fuels  Net migration  Diabetes Prevalance  \
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Score', 'Life Expectancy', 'GDP Per Capita', 'Crime Index',
#        'Death Rate', 'Birth rate', 'Marriage rate', 'Divorce rate',
#        'Literacy rate', 'Electricity access', 'Unemployment rate',
#        'Fossil fuels', 'Net migration', 'Diabetes Prevalance',
#        'HIV Prevalance', 'Rights Strength', 'Women in Parliament',
#        'Car Accidents', 'Urban Population', 'Average Rainfall'],
#       dtype='object')

# %%
sns.pairplot(data, y_vars = ['Score'], x_vars = ['GDP Per Capita', 'Crime Index', 'Death Rate', 'Birth rate'], height = 5, aspect = 0.7, kind = 'reg')

# %%
sns.pairplot(data, y_vars = ['Score'], x_vars = ['Life Expectancy', 'Marriage rate', 'Car Accidents', 'Literacy rate'], height = 5, aspect = 0.7, kind = 'reg')

# %%
sns.pairplot(data, y_vars = ['Score'], x_vars = ['Unemployment rate', 'Fossil fuels', 'Net migration', 'Urban Population'], height = 5, aspect = 0.7, kind = 'reg')

# %%
sns.distplot(data['GDP Per Capita'])

# %%
data.loc[data['GDP Per Capita']==data['GDP Per Capita'].max()]
# Out:
#        Country  Score  Life Expectancy  GDP Per Capita  Crime Index  \
# 77  Luxembourg   7.09            82.79     114704.5942        29.07
#
#     Death Rate  Birth rate  Marriage rate  Divorce rate  Literacy rate  ...  \
# 77         7.1        10.3            3.2           2.1      84.530033  ...
#
#     Unemployment rate  Fossil fuels  Net migration  Diabetes Prevalance  \
# 77              5.363     83.331753          48704                  5.0
#
#     HIV Prevalance  Rights Strength  Women in Parliament  Car Accidents  \
# 77      39871.2042              3.0                 25.0            6.3
#
#     Urban Population  Average Rainfall
# 77            91.223             934.0
#
# [1 rows x 21 columns]

# %%
sns.lineplot(x='Life Expectancy', y = 'Score', data = data)

# %%
sns.heatmap(data.corr(), linewidths=.5)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
feature_cols = ['Life Expectancy', 'Marriage rate', 'Divorce rate', 'Unemployment rate',
       'Fossil fuels', 'Diabetes Prevalance', 'Rights Strength',
       'Women in Parliament', 'Car Accidents', 'Urban Population']

# %%
X = data[feature_cols]
y = data['Score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
X_train.head()
# Out:
#      Life Expectancy  Marriage rate  Divorce rate  Unemployment rate  \
# 37             72.54       11.00000      1.900000             10.760
# 10             75.20        9.20000      4.100000              4.595
# 24             54.36        6.01954      1.891477              3.680
# 101            67.79        6.01954      1.891477              4.453
# 72             79.27        9.50000      1.600000              6.229
#
#      Fossil fuels  Diabetes Prevalance  Rights Strength  Women in Parliament  \
# 37      97.928930                 17.2              5.0            14.932886
# 10      92.440375                  5.0              3.0            40.000000
# 24      69.312725                  6.0              6.0             8.571429
# 101     61.585361                 19.9              2.0            20.234604
# 72      97.621101                 11.2              2.0             4.687500
#
#      Car Accidents  Urban Population
# 37             9.7            42.730
# ...

# %%
y_train.head()
# Out:
# 37     4.166
# 10     5.323
# 24     3.083
# 101    5.653
# 72     5.197
# Name: Score, dtype: float64

# %%
X_train.shape
# Out:
# (102, 10)

# %%
X_test.shape
# Out:
# (45, 10)

# %%
linear = LinearRegression()

# %%
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = linear.predict(X_test)
pred
# Out:
# array([6.89902137, 5.88954458, 6.08159016, 5.36424127, 5.34326944,
#        4.83656199, 6.27200599, 4.07348382, 6.20827087, 5.06217651,
#        5.0843472 , 5.3313048 , 4.58767882, 6.69138327, 6.79038856,
#        5.57317394, 5.00715211, 6.54456154, 5.05748169, 4.62195843,
#        3.55612547, 5.29337922, 5.15508926, 6.1743294 , 6.119156  ,
#        7.08883735, 6.67602745, 5.46850211, 4.39808327, 5.92675914,
#        6.66781188, 5.10262121, 7.25204325, 4.62622886, 4.54700391,
#        4.19767133, 4.50760607, 4.20974609, 6.4388904 , 3.89554023,
#        6.4039351 , 6.13685767, 6.83865841, 5.21068599, 3.6050213 ])

# %%
predictions = pd.Series(data=pred, name="Prediction")

# %%
res = pd.concat([y_test.reset_index(), predictions], axis=1)[['Score', 'Prediction']]

# %%
res.head() #spejimai ir tikrosios reiksmes
# Out:
#    Score  Prediction
# 0  7.054    6.899021
# 1  6.046    5.889545
# 2  5.940    6.081590
# 3  4.799    5.364241
# 4  5.890    5.343269

# %%
linear.score(X_test, y_test) #modelio tikslumas
# Out:
# 0.6876927690624114

# %%
sns.distplot(y_test, bins = 15) #patikrinam ar modelis pavyko ir duomenu issidestymas normalus

# %%
coef = pd.DataFrame(data = linear.coef_, columns = ['Coefficient'], index = X_train.columns).sort_values(by=['Coefficient'],  ascending=False)

# %%
coef #didziausia koreliacija rezultatui turi Rights Strength
# Out:
#                      Coefficient
# Rights Strength         0.037071
# Life Expectancy         0.026075
# Urban Population        0.022822
# Diabetes Prevalance     0.016791
# Women in Parliament     0.011648
# Fossil fuels           -0.006400
# Divorce rate           -0.028079
# Car Accidents          -0.035755
# Unemployment rate      -0.040579
# Marriage rate          -0.080466

# %%
df = data.sort_values(by=['Score'], ascending=False)

# %%
df['Position'] = [n for n in range(1, len(df['Country'])+1)]

# %%
df.tail(10).sort_values(by=['Score'], ascending=True)
# Out:
#                       Country  Score  Life Expectancy  GDP Per Capita  \
# 121               South Sudan  2.853            58.74    16083.680360
# 24   Central African Republic  3.083            54.36      467.907441
# 0                 Afghanistan  3.203            65.98      502.115487
# 128                  Tanzania  3.231            66.39     1122.121810
# 111                    Rwanda  3.334            70.00      801.656187
# 144                     Yemen  3.380            66.44    16083.680360
# 79                     Malawi  3.410            65.62      411.552340
# 126                     Syria  3.462            76.06    16083.680360
# 16                   Botswana  3.488            69.86     7961.338140
# 51                      Haiti  3.597            64.99      754.587918
#
#      Crime Index  Death Rate  Birth rate  Marriage rate  Divorce rate  \
# 121    43.525455      10.459      35.010        6.01954      1.891477
# ...

# %%
df.sort_values(by=['Score'], ascending=False)[:10]
# Out:
#          Country  Score  Life Expectancy  GDP Per Capita  Crime Index  \
# 41       Finland  7.769            82.48     48685.85399        22.80
# 34       Denmark  7.600            81.40     59822.09296        24.25
# 100       Norway  7.554            82.94     75419.63487        35.32
# 55       Iceland  7.494            83.52     66944.82551        23.28
# 94   Netherlands  7.488            82.78     52447.83144        28.57
# 125  Switzerland  7.480            84.25     81993.72715        21.50
# 124       Sweden  7.343            83.33     51610.06606        49.35
# 95   New Zealand  7.307            82.80     42084.35337        39.55
# 23        Canada  7.278            82.96     46194.72523        39.51
# 6        Austria  7.246            82.05     50277.27509        21.37
#
#      Death Rate  Birth rate  Marriage rate  Divorce rate  Literacy rate  ...  \
# 41         9.90        8.60            4.5           2.5      84.530033  ...
# ...

# %%
df[df['Country'].isin(['Lithuania', 'Latvia', 'Estonia', 'Poland'])]
# Out:
#        Country  Score  Life Expectancy  GDP Per Capita  Crime Index  \
# 106     Poland  6.182            79.27     15595.22703        30.09
# 76   Lithuania  6.149            76.41     19455.45413        36.51
# 71      Latvia  5.940            75.73     17836.36489        36.77
# 39     Estonia  5.893            79.18     23659.87229        20.80
#
#      Death Rate  Birth rate  Marriage rate  Divorce rate  Literacy rate  ...  \
# 106        10.9        10.2            5.1           1.7      84.530033  ...
# 76         14.1        10.0            7.4           3.1      84.530033  ...
# 71         15.0        10.0            6.6           3.1      99.889310  ...
# 39         11.9        10.9            5.2           2.6      84.530033  ...
#
#      Fossil fuels  Net migration  Diabetes Prevalance  HIV Prevalance  \
# 106     90.087964        -146976                  6.1     20603.13387
# 76      67.993749        -163902                  3.8     31537.10793
# ...
